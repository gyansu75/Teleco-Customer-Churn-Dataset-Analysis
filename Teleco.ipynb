# %%
file = pd.read_csv('data3.csv')

# %%
import pandas as pd

# %%
file
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
file.shape # shape
# Out:
# (7043, 21)

# %%
file.info() # datatypes and there are no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
file.Churn
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
file.Contract
# Out:
# 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7043, dtype: object

# %%
churnrate = file[['Contract','Churn']]

# %%
churnrate
# Out:
#             Contract Churn
# 0     Month-to-month    No
# 1           One year    No
# 2     Month-to-month   Yes
# 3           One year    No
# 4     Month-to-month   Yes
# ...              ...   ...
# 7038        One year    No
# 7039        One year    No
# 7040  Month-to-month    No
# 7041  Month-to-month   Yes
# 7042        Two year    No
#
# [7043 rows x 2 columns]

# %%
mtm = churnrate[churnrate.Contract == 'Month-to-month']

# %%
mtm
# Out:
#             Contract Churn
# 0     Month-to-month    No
# 2     Month-to-month   Yes
# 4     Month-to-month   Yes
# 5     Month-to-month   Yes
# 6     Month-to-month    No
# ...              ...   ...
# 7033  Month-to-month    No
# 7034  Month-to-month   Yes
# 7035  Month-to-month    No
# 7040  Month-to-month    No
# 7041  Month-to-month   Yes
#
# [3875 rows x 2 columns]

# %%
oy = churnrate[churnrate.Contract == 'One year']

# %%
oy
# Out:
#       Contract Churn
# 1     One year    No
# 3     One year    No
# 9     One year    No
# 12    One year    No
# 16    One year    No
# ...        ...   ...
# 7022  One year    No
# 7031  One year    No
# 7036  One year    No
# 7038  One year    No
# 7039  One year    No
#
# [1473 rows x 2 columns]

# %%
ot = churnrate[churnrate.Contract == 'Two year']

# %%
ot.shape
# Out:
# (1695, 2)

# %%
oyes= oy[oy.Churn == 'Yes']
myes= mtm[mtm.Churn == 'Yes']
tyes= ot[ot.Churn == 'Yes']

# %%
oyes
# Out:
#       Contract Churn
# 173   One year   Yes
# 317   One year   Yes
# 320   One year   Yes
# 335   One year   Yes
# 495   One year   Yes
# ...        ...   ...
# 6869  One year   Yes
# 6918  One year   Yes
# 6972  One year   Yes
# 6996  One year   Yes
# 7021  One year   Yes
#
# [166 rows x 2 columns]

# %%
myes
# Out:
#             Contract Churn
# 2     Month-to-month   Yes
# 4     Month-to-month   Yes
# 5     Month-to-month   Yes
# 8     Month-to-month   Yes
# 13    Month-to-month   Yes
# ...              ...   ...
# 7018  Month-to-month   Yes
# 7026  Month-to-month   Yes
# 7032  Month-to-month   Yes
# 7034  Month-to-month   Yes
# 7041  Month-to-month   Yes
#
# [1655 rows x 2 columns]

# %%
tyes
# Out:
#       Contract Churn
# 104   Two year   Yes
# 268   Two year   Yes
# 336   Two year   Yes
# 811   Two year   Yes
# 975   Two year   Yes
# 1840  Two year   Yes
# 2003  Two year   Yes
# 2287  Two year   Yes
# 2424  Two year   Yes
# 2790  Two year   Yes
# 3040  Two year   Yes
# 3111  Two year   Yes
# 3439  Two year   Yes
# 3694  Two year   Yes
# 3779  Two year   Yes
# 3788  Two year   Yes
# 3803  Two year   Yes
# 3849  Two year   Yes
# 3971  Two year   Yes
# 4149  Two year   Yes
# 4272  Two year   Yes
# 4386  Two year   Yes
# 4513  Two year   Yes
# 4527  Two year   Yes
# 4539  Two year   Yes
# 4642  Two year   Yes
# 4698  Two year   Yes
# 4819  Two year   Yes
# 5050  Two year   Yes
# 5256  Two year   Yes
# 5334  Two year   Yes
# 5441  Two year   Yes
# 5541  Two year   Yes
# 5579  Two year   Yes
# 5581  Two year   Yes
# 5589  Two year   Yes
# 5947  Two year   Yes
# 6038  Two year   Yes
# 6289  Two year   Yes
# 6290  Two year   Yes
# 6398  Two year   Yes
# 6408  Two year   Yes
# ...

# %%
mc = myes.shape
yc = oyes.shape
tc = tyes.shape

# %%
mc = mc[0]
yc = yc[0]
tc = tc[0]

# %%
churnratem = mc * 100 / 3875
churnratey = yc * 100 / 1437
churnratet = yc * 100 / 1695

# %%
print('the Churn rate for Month-to-month is {}',format(churnratem))
print('the Churn rate for One year is {}',format(churnratey))
print('the Churn rate for Two year is {}',format(churnratet))
# Out:
# the Churn rate for Month-to-month is {} 42.70967741935484
# the Churn rate for One year is {} 11.551844119693806
# the Churn rate for Two year is {} 9.793510324483776

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Churn Rate

# %%
plt.bar('Monthly Contracts',churnratem)
plt.bar('One Year Contracts',churnratey)
plt.bar('Two Year Contracts',churnratet)
plt.xlabel('Churn Rates')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# # Variation in Tenure

# %%
ten = file['tenure']

# %%
tenu = ten.unique()

# %%
tenu
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
plt.figure(figsize = (8,4))
plt.plot(tenu)

# %%
mean =int( tenu.mean())

# %%
mean
# Out:
# 36

# %%
longer = file[file.tenure > mean]

# %%
longer.shape
# Out:
# (3001, 21)

# %%
short = file[file.tenure <= mean]

# %%
short.shape
# Out:
# (4042, 21)

# %%
con = file['Contract']

# %%
conuni = con.unique()

# %%
conuni
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
longeryes = longer[longer.Churn == 'Yes']
shorteryes = short [short.Churn == 'Yes']

# %%
shorteryes.shape
# Out:
# (1511, 21)

# %%
longeryesrate = 358 *100 / 3001
shorteryesrate = 1511 * 100 / 4042

# %%
plt.bar('> 36',longeryesrate)
plt.bar('<= 36 ',shorteryesrate)

plt.xlabel('Duration')
plt.ylabel('Churn Percentage(%)')
# Out:
# Text(0, 0.5, 'Churn Percentage(%)')
